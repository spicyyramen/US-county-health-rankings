# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
from urllib.request import urlopen
import json

# %%
# %run preprocessing.ipynb

# %%
df2
# Out:
#        State         County  State code  County code  Year span  \
# 0         US  United States           0            0  2003-2005
# 1         US  United States           0            0  2004-2006
# 2         US  United States           0            0  2005-2007
# 3         US  United States           0            0  2006-2008
# 4         US  United States           0            0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303478    WY  Weston County          56           45       2007
# 303479    WY  Weston County          56           45       2008
# 303480    WY  Weston County          56           45       2009
# 303481    WY  Weston County          56           45       2010
# 303482    WY  Weston County          56           45       2011
#
#                          Measure name  Measure id    Numerator  Denominator  \
# 0                  Violent crime rate          43  1328750.667  274877117.0
# ...

# %% [markdown]
# # Look at Violent Crime Rates in California

# %%
# open counties location file
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
# create animated map of violent crime rates across Year Spans
fig = px.choropleth(df2.loc[(df2['State'] == 'CA')&(df2['County']!= "California") & (df2['Measure name'] == "Violent crime rate")], 
                    geojson=counties, 
                    locations='FIPS Code', 
                    color='Raw value',
                           color_continuous_scale="turbo",
                           range_color=(0, 700),
                           scope="usa",
                            title='<b>Violent Crime Rates in California by County',
                           labels={'Raw value':'Violent Crime Rate',
                                  'fipscode':'FIPS Code'},
                            hover_name = 'County',
                    animation_frame="Year span"
                          )
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0},
                 height=600,
                 width=800)
# Adjust map geo options
fig.update_geos(showcountries=False, showcoastlines=True,
                fitbounds="locations",
                )
fig.show()
